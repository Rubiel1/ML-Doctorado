# %% [markdown]
# ### CICATA

# %% [markdown]
# 8 de Agosto del 2019

# %% [markdown]
# Dr. Eric Dolores,
# matemático en NewSci labs.

# %% [markdown]
# Aqui les compartire lo que en mi experiencia es el camino mas sencillo para que un estudiante de postgrado aprenda ML.

# %% [markdown]
# ### Motivacion.

# %% [markdown]
# En FSU creamos una clase de ML para estudiantes de doctorado con nociones básicas de programación.
#
# https://mendozacortesgroup.github.io/MachineLearningForHumans/

# %% [markdown]
# Abajo vemos dos imagenes, en una removimos objetos usando ML en 2 segundos.

# %%
from IPython.display import Image

# %%
Image("img/carlos.png")

# %%
Image("img/Carlo.jpg")

# %% [markdown]
# Ejemplo de edición de imagen.
#
# https://www.nvidia.com/research/inpainting/selection

# %% [markdown]
# Lo importante es que el proceso no requiere conocimientos de herramientas de edicion y fue relativamente rapido.

# %% [markdown]
# Abajo vemos un ejemplo de un algorithm que traduce, solo que en ves de traducir de un idioma a otro, traduce de selfie a anime, o de caballo a cebra, gato a perro, etc.

# %%
Image("img/gan.jpg")

# %% [markdown]
# Traducción de imagen.
#
# [Photo credit: @roadrunning01]

# %% [markdown]
# Quizas una de las aplicaciones mas conocidas, ha sido en el ajedrez, donde a un algoritmo (voy a mentir un poco en estas notas) se le dieron las reglas de ajedrez, y el algoritmo jugo consigo mismo. Se le dio una manera de evaluar su juego y el algoritmo buscaba maneras de mejorar la evaluacion.
#
# Como el algoritmo nunca vio juegos de humanos, no aprendio de nosotros nuestros errores.
#
# Sus juegos se han describido como raros, porque al usar sus propias estrategias hace cosas que no habiamos considerado. Abajo vemos dos videos donde Maestros del ajedrez se maravillan por las jugadas del algoritmo. Ahora son los humanos los que tienen que aprender de esta maquina.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('YgZEaP6Qte0?t=249')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/YgZEaP6Qte0?t=249"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo('lFXJWPhDsSY?t=654')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/lFXJWPhDsSY?t=654"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Se ha calculado que el Nivel ELO de el algoritmo es 3200, un valor superior a lo que los mejores ajedrecistas jamas han alcanzado.

# %% [markdown]
# Elo:
#
#     2882	Magnus Carlsen
#     3200    Alpha Zero

# %% [markdown]
# ### Ejemplos en Ciencias

# %% [markdown]
# El mismo equipo que trabajo con el algoritmo de ajedrez, uso sus tecnicas
# para atacar un problema imporante para la ciencia.

# %% [markdown]
# Si sabemos que aminoacidos se necesitan en una proteina, podemos predecir la estructura de la proteina? esto es muy importante porque muchas enfermedades son resultado de protenias con errores en su estructura.

# %% [markdown]
# https://deepmind.com/blog/alphafold/

# %% [markdown]
# Abajo tenemos el resultado de trabajo realizado en la Universidad de Northwestern.
#
# El algoritmo usa nociones avanzadas de algebra, pero la explicacion es sencilla:

# %% [markdown]
# Durante dos anios anotamos la interaccion de pacientes con problemas en el corazon. En una tabla ponemos como columnas los medicamentos y como renglones el diagnostico.
#
# Si tenemos un paciente con enfermedad 'y' y se le dio la medicina 'x', entonces ponemos  1 en la interseccion del renglon 'y' y columna 'x', y ponemos zero en los demas valores. Asi a cada paciente le asigmanos una matriz con la mayoria de las entradas zero.  Y ahora consideramos un nuevo eje, el de el paciente, y ponemos las matricies por cada paciente. Terminaremos con una matriz de tres dimensiones.

# %%
Image("img/tensor.png")

# %% [markdown]
# A esta matriz la llamamos tensor eh intentamos factorizarla en suma de tensores irreducibles.

# %% [markdown]
# Factorizacion en tensores de rango uno muestra dianosticos concurrentes con medicacion, este proceso es llamado fenotipo. El estudio de fenotipos en machine learning permitio el descubrimiento de grupos distintos de Hearth Failure with preserved Ejection Fractions (HFpEF), esos grupos diferian marcadamente en caracteristicas clinicas, de estructura/funcion, para mas detalles ver:
#
#      Phenomapping for Novel Classification of Heart Failure With Preserved Ejection Fraction Sanjiv J. Shah, MD (2016)
#
# [Photo credit: Marble: High-throughput Phenotyping from Electronic
# Health Records via Sparse Nonnegative Tensor
# Factorization]

# %% [markdown]
# A continuacion vemos los ultimos avances de ML en Ciencia de Materiales:

# %% [markdown]
#  https://community.apan.org/wg/afosr/w/researchareas/22949/scientific-autonomous-reasoning-agent-sara-integrating-materials-theory-experiment-and-computation/

# %% [markdown]
# Tambien les recomiendo visitar el siguiente Webinar:

# %% [markdown]
# Machine Learning, AI, and Data Driven Materials Development and Design.

# %%
YouTubeVideo('DBknkNvYlcE')

# %% [markdown]
# El siguiente articulo busca usar ML en el estudio de estructuras de cristales: Crystal Structure Prediction via Deep Learning

# %% [markdown]
# https://pubs.acs.org/doi/10.1021/jacs.8b03913

# %% [markdown]
# Aqui el problema es que la informacion consiste de coordenadas y labels (atomo de H en la posicion (1,.003,4), etc).
# Asi que primero se construyen imagenes que son invariantes de la eleccion de la celda unitaria.

# %% [markdown]
# ### ML en accion.

# %% [markdown]
# El siguiente tutorial les muestra la creación de un clasificador.

# %% [markdown]
# http://www.r2d3.us/una-introduccion-visual-al-machine-learning-1/

# %% [markdown]
# Si ya saben que es una red neuronal, aqui pueden mejorar su intuicion.
# http://playground.tensorflow.org/

# %% [markdown]
# ### De verdad necesito ML?

# %%
Image("img/fomo.jpg")

# %% [markdown]
# [Photo credit: PlusLexia.]

# %% [markdown]
# ¿Le conviene a los estudiantes aprender sobre ML? si el estudiante decide no seguir por el rumbo académico, podrá trabajar como científico de datos.

# %% [markdown]
# ¿Necesito machine learning? Yo respondo esa pregunta con otra pregunta: ¿Tienes una cantidad considerable de datos o planeas obtener miles-millones de datos? Los metodos usuales como la regresion o SVM son suficientemente buenos cuando uno trabaja con pocos datos. Las redes neuronales tienen un mejor desempenio cuando se maneja big data, miles o millones de datos:

# %%
Image("img/nn.png")

# %% [markdown]
# [Photo credit: Andrew Ng]

# %% [markdown]
# ¿Qué matemáticas necesito estudiar? Cálculo de varias variables, álgebra lineal, probabilidad...

# %% [markdown]
# Esta es un area muy informal, pero hay trabajo de fisicos intentando crear las bases por ejemplo:

# %% [markdown]
# https://arxiv.org/abs/1608.08225   usando física se ha intentado explicar el funcionamiento de las redes neuronales.

# %% [markdown]
# ¿Qué deberian saber mis estudiantes?

# %%
Image("img/pylogo.png")

# %% [markdown]
# (Python)

# %% [markdown]
# El curso mas sencillo de Python.
#
# https://runestone.academy/runestone/books/published/thinkcspy/index.html

# %%
Image("img/sklearn.png")

# %% [markdown]
# 80% de los problemas se resuelven con sklearn.

# %% [markdown]
# Si estas en el caso de big data, no recomiendo usar redes neuronales en sklearn, es mejor usar KERAS:

# %%
Image("img/keras.png")

# %% [markdown]
# Keras es una libreria que te permite crear redes neuronales.

# %% [markdown]
# Una vez que estes familiarizado puedes experimentar con pytorch, que tiene mensajes de error mas sencillos de entender y otras propiedades que dan flexibilidad.

# %%
Image("img/pytorch.png")

# %% [markdown]
# Pytorch.

# %% [markdown]
# Y ya que estoy dando recomendaciones, les sugiero el siguiete sofware para crear graficas interactivas, vean el link:

# %%
Image("img/altair.png")

# %% [markdown]
# Altair.
# https://altair-viz.github.io/gallery/scatter_linked_brush.html

# %% [markdown]
# Para estar al dia en ML estas son las cuentas en Twitter a seguir:

# %% [markdown]
#     @drfeifei : Fei-Fei Li - Director of Stanford AI Lab, creator of ImageNet
#     @ylecun: (Yann LeCun) Leading Facebook AI/ML Research
#     @karpathy : Andrej Karpathy - Teaches Deep Learning at Stanford, Research Scientist at OpenAI
#     @AndrewYNg ( Andrew Ng) : Led ML research in google, now leads AI research in Baidu
#     @Kdnuggets ( Gregory Piatetsky) : Leading KDnuggets - tweets/retweets lots of relevant stuff.
#     @OpenAI
#     @googleresearch
#     @BaiduResearch

# %% [markdown]
# Aqui hay una sugerencia de projectos posibles en Mexico:

# %% [markdown]
# Calentamiento global.

# %% [markdown]
# https://arxiv.org/pdf/1906.05433.pdf Este archivo nos dice las posibles areas donde se puede empezar a trabajar y los correspondientes algoritmos que se podrian usar.

# %% [markdown]
# (Denuncia anónima) un Doctor del IMSS opera a pacientes para implantar prótesis de rodilla en casos innecesarios. Si alguien tiene accesso a informacion del IMSS se puede usar SVM para ver si su comportamiento es abnormal, y con evidencia estadistica pedir que otros medicos revisen si se esta comentiendo alguna arbitrariedad.
#
# (Busqueda de fraude) se puede analizar si los miembros del SNI cambian sus patrones de publicación, y si lo hacen de manera abrupta, verificar sus artículos para evitar fraude. Esto es muy comun en areas como la quimica donde las revistas no pueden reproducir los experimentos, pues muchos de esos experimentos toman anios.

# %% [markdown]
# ### Posibles problemas.

# %% [markdown]
# En las noticias decian que de cada  20 projectos de IA, solo tres son exitosos. Algunas razones son:

# %% [markdown]
# - Plausibilidad. Es posible resolver tu problema con ML? Esto se soluciona hablando con expertos.
# - Ya tienes los datos o necesitas a alguien que los capture. Esta es la parte mas delicada y que consume mas tiempo.
# - Analizis y preprocesamiento de datos. Hay que establecer contacto con quien recogio los datos, ver que fue de manera objetiva, que notacion usaron, etc.
# - Equipo. Tienes la capacidad de trabajar con big data?
# - Infra estructura. Si es una interaccion internacional y se necesita interactuar, quizar crear una aplicacion, etc.
# - Interpretacion de resultados. Es importante tener una fundacion de matematicas que te permita entender los resultados. Esta es la razon por la que los p-values estan cayendo de moda en la estadistica. Nunca dieron un si o un no, sino que nos daban evidencia.

# %% [markdown]
# En la parte de recoleccion de datos, se necesita verificar que se hace de manera objetiva, por ejemplo, nosotros descubrimos prejuicios en los algoritmos de un escaner en 3d cuando creabamos la exhibición 'adaptation'.  https://www.sciartmagazine.com/straight-talk-justus-harris.html
#
# Basicamente, no pudimos escanear la imagen de una mujer por su tez obscura. El algoritmo tambien se usa en jugetes, y es muy triste que un ninio de tes cafe no pueda usar el jugete mientras un ninio blanco si. Es peligroso que un coche no reconozca a los mexicanos solo porque fue creado en EU y solo les intereso que reconozca a la gente de piel blanca.
#
# Recomendamos tomar el curso en equidad de Google https://developers.google.com/machine-learning/crash-course/fairness/video-lecture?utm_campaign=mle-outreach&utm_medium=blog&utm_source=keyword-blog&utm_content=mlcc-fairness

# %% [markdown]
# En tu projecto es importante delimitar responsabilidades, pues enterder algoritmos de ML y crear la base de datos requiren conocimientos distitos:

# %%
Image("img/roles.png")

# %% [markdown]
# [Photo credit: Google]

# %% [markdown]
# Yo recomiendo (sin que ellos me lo pidieran) GCP.

# %%
Image("img/gcp.png")

# %% [markdown]
# Google Cloud Platform tiene herramientas de machine learning con big data en tres niveles.
#
#     -Automatico para gente sin conocimientos de programacion.
#     -Sql te permite usar algoritmos predeterminados.
#     -TensorFlow para gente con experiencia en ML.

# %% [markdown]
# Y ellos tienen planes para investigacion:

# %% [markdown]
# https://edu.google.com/intl/es-419/why-google/higher-ed-solutions/?modal_active=none

# %%
Image("img/slack.jpg")

# %% [markdown]
# Nosotros tenemos un grupo en slack sobre ML en la ciencia. Aqui la gente compila aplicaciones y articulos cientificos que usan ML:

# %% [markdown]
# https://tinyurl.com/FSUMachineLearning

# %%
Image("img/NewSci.png")

# %% [markdown]
# ¿Dudas sobre la plausibilidad de su projecto? contactenos ericd@newsci.ai
